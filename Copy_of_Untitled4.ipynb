# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha1608/Task-01/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''username = "admin"
password = "1234"
input_username = input("Enter username : ")
input_password = input("Enter Your password " )
if input_username == username and input_password == password:
    print("Login Successful")
else:
    print("Invalid Credentials")'''
# Out:
# 'username = "admin"\npassword = "1234"\ninput_username = input("Enter username : ")\ninput_password = input("Enter Your password " )\nif input_username == username and input_password == password:\n    print("Login Successful")\nelse:\n    print("Invalid Credentials")'

# %%
'''marks = [45, 78, 90, 33,60]
pass_count = 0
fail_count = 0
for mark in marks:
    if mark >= 50:
        pass_count +=1
    else:
        fail_count +=1
print("Total Students :", len(marks))
print("Passed Students :", pass_count)
print("Failed Students :", fail_count)'''
# Out:
# 'marks = [45, 78, 90, 33,60]\npass_count = 0\nfail_count = 0\nfor mark in marks:\n    if mark >= 50:\n        pass_count +=1\n    else:\n        fail_count +=1\nprint("Total Students :", len(marks))        \nprint("Passed Students :", pass_count)\nprint("Failed Students :", fail_count)'

# %%
''' names = [" Alice ", "bob", " CHARLIE "]
cleaned_names = []
# Out:
#   File "/tmp/ipython-input-1898369774.py", line 1
#     ''' names = [" Alice ", "bob", " CHARLIE "]
#     ^
# SyntaxError: incomplete input

# %%
'' names = [" Alice ", "bob", " CHARLIE "]
cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)
print("Cleaned Names :", cleaned_names)'''
# Out:
#   File "/tmp/ipython-input-4019549970.py", line 7
#     print("Cleaned Names :", cleaned_names)'''
#                                            ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 7)

# %%
''' messages = ["Hi", "Welcome to the platform", "OK"]
for msg in messages:
     length = len(msg)
     print("Message :",msg)
     print("Length :",length)
     if length >10:
         print("Flag")
     print("No Flag")'''
# Out:
# ' messages = ["Hi", "Welcome to the platform", "OK"]\nfor msg in messages:\n     length = len(msg)\n     print("Message :",msg)\n     print("Length :",length)\n     if length >10:\n         print("Flag")\n     print("No Flag")'

# %%
'''logs = ["INFO", "ERROR", "WARNING", "ERROR"]
error_count = logs.count("ERROR")
print("Total ERROR entries :", error_count)'''
# Out:
# 'logs = ["INFO", "ERROR", "WARNING", "ERROR"]\nerror_count = logs.count("ERROR")\nprint("Total ERROR entries :", error_count)'
